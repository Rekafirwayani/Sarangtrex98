# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarangtrex98/Sarangtrex98/blob/main/WEB%20SCRAPING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install 'google-play-scraper'
# Out:
# ...
#      |████████████████████████████████| 61kB 3.6MB/s
# ...
#   Created wheel for google-play-scraper: filename=google_play_scraper-1.0.0-cp37-none-any.whl size=24070 sha256=c1caac40d19eaa6203afea264b515a91e2a8ee5ab9c72fbad615886de4cd1198
#   Stored in directory: /root/.cache/pip/wheels/e9/98/5a/917dd15a6f100d35a26c5f6f0ae99895ae861aff74fafa1b08
# Successfully built google-play-scraper
# ...

# %%
from google_play_scraper import Sort, reviews_all
result = reviews_all(
    'com.tanihub.vaesdothrak',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    # filter_score_with=defaults # defaults to None(means all score)
)

# %%
result
# Out:
# [{'at': datetime.datetime(2021, 5, 26, 10, 36, 4),
#   'content': 'Good products, good service, especially now with min purchase of 50k I can get free delivery. I always order from Tanihub 1-2×/week. I hope you can add more varieties such as portobello mushroom, more herbs, more fruits, and (frozen) potato wedges too 😍',
#   'repliedAt': datetime.datetime(2020, 5, 18, 8, 44, 14),
#   'replyContent': 'Hi Della,Terima kasih atas masukannya dan mohon maaf atas ketidaknyamanan yang dialami.Ini akan menjadi perbaikan aplikasi kami agar lebih baik lagi.Slain menggunakan aplikasi,saat ini Anda bisa berbelanja melalui website kami di www.tanihub.com.Mohon dapat menginformasikan detail kendala Anda di help@tanihub.com agar tim CS kami dpt membantu Anda',
#   'reviewCreatedVersion': '1.65.1',
#   'reviewId': 'gp:AOqpTOEzT6u7L_9sjEbljr83oqPtAbcK_roq9VB-hHi9ZftoMcbkQzYp9N7gFplvgmKxdO6og0Xwj_Qz8hE',
#   'score': 5,
#   'thumbsUpCount': 13,
# ...
